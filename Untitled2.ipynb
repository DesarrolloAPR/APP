# %% [markdown]
# <a href="https://colab.research.google.com/github/DesarrolloAPR/APP/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.1 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/DesarrolloAPR/APP.git
# %cd TU_REPOSITORIO
# Out:
# Cloning into 'APP'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 35 (delta 15), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 12.80 KiB | 1.83 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# [Errno 2] No such file or directory: 'TU_REPOSITORIO'
# /content

# %%
# !python APP/
# Out:
# /usr/bin/python3: can't find '__main__' module in '/content/APP/'

# %%
import os

# Definir la ruta base
base_path = '/content/datasets'

# Lista de carpetas a crear
folders = [
    'train/images',
    'train/labels',
    'val/images',
    'val/labels'
]

for folder in folders:
    os.makedirs(os.path.join(base_path, folder), exist_ok=True)

print("✅ Estructura de carpetas creada en:", base_path)
# Out:
# ✅ Estructura de carpetas creada en: /content/datasets
